# %%
pip install scikeras

# %%
pip install scikit-learn==1.5.2

# %%
# bibliotecas
import pandas as pd
import tensorflow as tf
import sklearn
import scikeras

# %%
pd.__version__, tf.__version__, sklearn.__version__, scikeras.__version__ # version
# Out:
# ('2.2.2', '2.20.0', '1.5.2', '0.13.0')

# %%
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import cross_val_score
from tensorflow.keras.models import Sequential
from tensorflow.keras import backend as k

# %%
X = pd.read_csv('/content/entradas_breast.csv') # leitura do csv de entrada
y = pd.read_csv('/content/saidas_breast.csv') # leitura do csv de saida

# %%
from keras.src import optimizers
def criar_rede():
  k.clear_session()
  rede_neural = Sequential([
      tf.keras.layers.InputLayer(shape = (30,)),
      tf.keras.layers.Dense(units = 16, activation= 'relu', kernel_initializer = 'random_uniform'),
      tf.keras.layers.Dropout(rate=0.2),
      tf.keras.layers.Dense(units = 16, activation= 'relu', kernel_initializer= 'random_uniform'),
      tf.keras.layers.Dropout(rate=0.2),
      tf.keras.layers.Dense(units = 1, activation= 'sigmoid')])
  otimizador = tf.keras.optimizers.Adam(learning_rate = 0.001, clipvalue = 0.5)
  rede_neural.compile(optimizer = otimizador, loss = 'binary_crossentropy', metrics = ['binary_accuracy'])
  return rede_neural

# %%
rede_neural = KerasClassifier(model = criar_rede, epochs= 100, batch_size= 10)

# %%
resultados = cross_val_score(estimator = rede_neural, X = X, y = y, cv = 10, scoring = 'accuracy')
# Out:
# Epoch 1/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - binary_accuracy: 0.5840 - loss: 0.9275
# Epoch 2/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.6836 - loss: 0.6371
# Epoch 3/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.7090 - loss: 0.6320
# Epoch 4/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.6836 - loss: 0.6261
# Epoch 5/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.6914 - loss: 0.6464
# Epoch 6/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.7344 - loss: 0.6239
# Epoch 7/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.7480 - loss: 0.5547
# Epoch 8/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.7305 - loss: 0.6180
# Epoch 9/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.7598 - loss: 0.6329
# Epoch 10/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.7656 - loss: 0.5468
# Epoch 11/100
# ...

# %%
resultados
# Out:
# array([0.8245614 , 0.73684211, 0.75438596, 0.87719298, 0.70175439,
#        0.92982456, 0.73684211, 0.80701754, 0.68421053, 0.83928571])

# %%
resultados # com dropout
# Out:
# array([0.87719298, 0.89473684, 0.87719298, 0.94736842, 0.87719298,
#        0.89473684, 0.87719298, 0.92982456, 0.87719298, 0.92857143])

# %%
resultados.mean() # media da acuracia sem DropOut
# Out:
# np.float64(0.7891917293233083)

# %%
resultados.std() # calculando o desvio padrão da média sem dropOut
# Out:
# np.float64(0.07547101719887199)

# %%
resultados.mean() # media da acuracia com DropOut
# Out:
# np.float64(0.8981203007518797)

# %%
resultados.std() # calculando o desvio padrão da média com dropOut
# Out:
# np.float64(0.025632923208617736)
