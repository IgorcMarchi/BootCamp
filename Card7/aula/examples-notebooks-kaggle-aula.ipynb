# %% [markdown]
# # Example Kaggle Notebook
#
# Isso é ótimo

# %%
print('test test 123')
# Out:
# test test 123

# %%
import pandas as pd

# %%
# importando o arquivo csv
df = pd.read_csv('../input/mrbeast-youtube-stats-daily/MrBeast_youtube_stats.csv')

# %%
# topo do dataframe
df.head()
# Out:
#             id                             title  \
# 0  8bTQMDM4qvY  Spot The Fake Animal For $10,000
# 1  QtD-CeUdRUQ          Real Or Cake For $10,000
# 2  3dxksf0CzS8           World’s Fastest Robbers
# 3  EvqtfK_RaRg      This obstacle course is WILD
# 4  M1STzb7k9L8               Extreme Helmet Game
#
#                                     description                publishTime  \
# 0                                           NaN  2024-07-19 16:00:00+00:00
# 1                                           NaN  2024-08-29 16:00:00+00:00
# 2  That robber kinda looks like @DanielLaBelle.  2025-05-02 16:00:00+00:00
# 3                                           NaN  2025-01-10 17:00:00+00:00
# 4                                           NaN  2025-04-25 16:15:00+00:00
#
#       kind_stats  duration_seconds    viewCount   likeCount  commentCount  \
# 0  youtube#video                40  592535297.0  16909810.0       28617.0
# 1  youtube#video                37  231997872.0   7720839.0       17847.0
# 2  youtube#video                32  232943879.0   5191680.0       12588.0
# 3  youtube#video                32  203722930.0   3845805.0        5347.0
# 4  youtube#video                23  204994821.0   2227867.0        5054.0
#
#                            thumbnails.default.url  ...  thumbnails.high.width  \
# 0  https://i.ytimg.com/vi/8bTQMDM4qvY/default.jpg  ...                  480.0
# 1  https://i.ytimg.com/vi/QtD-CeUdRUQ/default.jpg  ...                  480.0
# 2  https://i.ytimg.com/vi/3dxksf0CzS8/default.jpg  ...                  480.0
# 3  https://i.ytimg.com/vi/EvqtfK_RaRg/default.jpg  ...                  480.0
# 4  https://i.ytimg.com/vi/M1STzb7k9L8/default.jpg  ...                  480.0
#
#    thumbnails.high.height contentDetails.duration  contentDetails.dimension  \
# 0                   360.0                   PT40S                        2d
# 1                   360.0                   PT37S                        2d
# 2                   360.0                   PT32S                        2d
# 3                   360.0                   PT32S                        2d
# 4                   360.0                   PT23S                        2d
#
#                         topicDetails.topicCategories snippet.defaultLanguage  \
# 0    ['https://en.wikipedia.org/wiki/Entertainment']                      en
# 1    ['https://en.wikipedia.org/wiki/Entertainment']                      en
# 2  ['https://en.wikipedia.org/wiki/Entertainment'...                      en
# 3    ['https://en.wikipedia.org/wiki/Entertainment']                      en
# 4    ['https://en.wikipedia.org/wiki/Entertainment']                      en
#
#              localizations.en.title  \
# 0  Spot The Fake Animal For $10,000
# 1          Real Or Cake For $10,000
# 2           World’s Fastest Robbers
# 3      This obstacle course is WILD
# 4               Extreme Helmet Game
#
#                   localizations.en.description snippet.tags  \
# 0                                          NaN          NaN
# 1                                          NaN          NaN
# 2  That robber kinda looks like @DanielLaBelle          NaN
# 3                                          NaN          NaN
# 4                                          NaN          NaN
#
#                           pull_date
# 0  2025-10-21 00:05:32.404305+00:00
# 1  2025-10-21 00:05:32.404305+00:00
# 2  2025-10-21 00:05:32.404305+00:00
# 3  2025-10-21 00:05:32.404305+00:00
# 4  2025-10-21 00:05:32.404305+00:00
#
# [5 rows x 26 columns]

# %%
# cria um gráfico mostrando a relação dos likes com as vizualizações
df.plot(x='viewCount', y='likeCount', kind='scatter', title='Mr. Beast Videos')
# Out:
# <Axes: title={'center': 'Mr. Beast Videos'}, xlabel='viewCount', ylabel='likeCount'>
