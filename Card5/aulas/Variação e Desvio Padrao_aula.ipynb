# %%
import numpy as np
import matplotlib.pyplot as plt
incomes = np.random.normal(100.0, 20.0, 10000) # gera dados com média 100 e desvio 20
plt.hist(incomes, 50) # cria um histograma de 50
plt.show()

# %%
incomes.std() #desvio padrão
# Out:
# 19.96121616125024

# %%
incomes.var() #variancia
# Out:
# 398.4501506361577
