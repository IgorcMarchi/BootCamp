# %%
import torch
import torch.nn as nn
import numpy as np
from torch.utils.data import Dataset, DataLoader
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
x = [[1,2],[3,4],[5,6],[7,8]]
y = [[3],[7],[11],[15]]

# %%
class MyDataset(Dataset):
    def __init__(self,x,y):
        self.x = torch.tensor(x).float().to(device)
        self.y = torch.tensor(y).float().to(device)
    def __len__(self):
        return len(self.x)
    def __getitem__(self,ix):
        return self.x[ix], self.y[ix]

# %%
ds = MyDataset(x,y)
dl = DataLoader(ds, batch_size=2, shuffle=True)

# %%
# No modelo é definido 2 camada linear, função de ativação ReLU e novamente uma outra camada linear(8)
model = nn.Sequential(nn.Linear(2,8),
                      nn.ReLU(),
                      nn.Linear(8,1).to(device))

# %%
model
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=8, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=8, out_features=1, bias=True)
# )

# %% [markdown]
# ## Training the Model

# %%
loss_func = nn.MSELoss() # função de loss
from torch.optim import SGD
opt = SGD(model.parameters(), lr = 0.001)
import time
loss_history = []
start = time.time()

model.train() # função para treinar o modelo
for _ in range(50): # carrega um for de 50 epocas
    for ix, iy in dl:
        opt.zero_grad()
        loss_value = loss_func(model(ix),iy)
        loss_value.backward()
        opt.step()
        loss_history.append(loss_value)
end = time.time()
# só cronometra quanto tempo o treino demorou
print(end - start)
# Out:
# 0.26337170600891113

# %% [markdown]
# ## Predicting on a validation dataset

# %%
val = [[8,9], [10,11], [1.5, 2.5]]

# %%
model(torch.tensor(val).float().to(device))
# Out:
# tensor([[16.9522],
#         [20.9159],
#         [ 4.0704]], grad_fn=<AddmmBackward0>)
